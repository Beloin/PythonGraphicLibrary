# %%
import raster
import wireframe
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# %%
# TODO: Yet we need to project on 2D plane
scale_x, scale_y = (500, 500)
scale = (scale_x, scale_y)

edge = wireframe.cube(.5, origin=.1, res=.05, dist=.2)

polygon = raster.draw_edge_list(edge.raw(), scale)

mx = [[0 for _ in range(scale_x)] for _ in range(scale_y)]
raster.insert_points(mx, polygon)

plt.imshow(raster.convert_img(mx))
plt.show()

# %%
fig = plt.figure()
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

fig = plt.figure()
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

edges = wireframe.cube(.5, dist=.2)
verts = []
for vec3d in edges:
    tmp = [0]
    tmp.extend(vec3d[0])
    verts.append(tmp)    

ax.add_collection3d(Poly3DCollection(verts))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 16
#      13     tmp.extend(vec3d[0])
#      14     verts.append(tmp)
# ---> 16 ax.add_collection3d(Poly3DCollection(verts))
#      17 plt.show()
#
# File ~/Documents/aulas/10_sem/cg/render_py/venv/lib/python3.11/site-packages/mpl_toolkits/mplot3d/art3d.py:887, in Poly3DCollection.__init__(self, verts, zsort, shade, lightsource, *args, **kwargs)
#     883     if facecolors is None and edgecolors in None:
#     884         raise ValueError(
#     885             "You must provide facecolors, edgecolors, or both for "
#     886             "shade to work.")
# --> 887 super().__init__(verts, *args, **kwargs)
#     888 if isinstance(verts, np.ndarray):
#     889     if verts.ndim != 3:
#
# File ~/Documents/aulas/10_sem/cg/render_py/venv/lib/python3.11/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/Documents/aulas/10_sem/cg/render_py/venv/lib/python3.11/site-packages/matplotlib/collections.py:1172, in PolyCollection.__init__(self, verts, sizes, closed, **kwargs)
#    1170 super().__init__(**kwargs)
#    1171 self.set_sizes(sizes)
# -> 1172 self.set_verts(verts, closed)
#    1173 self.stale = True
#
# File ~/Documents/aulas/10_sem/cg/render_py/venv/lib/python3.11/site-packages/mpl_toolkits/mplot3d/art3d.py:943, in Poly3DCollection.set_verts(self, verts, closed)
#     929 def set_verts(self, verts, closed=True):
#     930     """
#     931     Set 3D vertices.
#     932
#    (...)
#     941         connection at the end.
#     942     """
# --> 943     self.get_vector(verts)
#     944     # 2D verts will be updated at draw time
#     945     super().set_verts([], False)
#
# File ~/Documents/aulas/10_sem/cg/render_py/venv/lib/python3.11/site-packages/mpl_toolkits/mplot3d/art3d.py:920, in Poly3DCollection.get_vector(self, segments3d)
#     918 """Optimize points for projection."""
#     919 if len(segments3d):
# --> 920     xs, ys, zs = np.row_stack(segments3d).T
#     921 else:  # row_stack can't stack zero arrays.
#     922     xs, ys, zs = [], [], []
#
# ValueError: too many values to unpack (expected 3)

# %%
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import matplotlib.pyplot as plt
fig = plt.figure()
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)
x = [0,1,1,0]
y = [0,0,1,1]
z = [0,1,0,1]
a = list(zip(x,y,z))
verts = [a]
ax.add_collection3d(Poly3DCollection(verts))
plt.show()
