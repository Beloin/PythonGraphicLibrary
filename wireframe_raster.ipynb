# %%
import raster
import wireframe
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# %%
# TODO: Yet we need to project on 2D plane
scale_x, scale_y = (500, 500)
scale = (scale_x, scale_y)

edge = wireframe.cube(.5, res=.1, dist=.2)

polygon = raster.draw_edge_list(edge.raw(), scale)

mx = [[0 for _ in range(scale_x)] for _ in range(scale_y)]
raster.insert_points(mx, polygon)

plt.imshow(raster.convert_img(mx))
plt.show()

# %%
fig = plt.figure()
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

edges = wireframe.cube(1, res=.5)

poly = []
verts = []
counter = 0
for vec3d in edges:
    p1 = vec3d[0]
    verts.append(p1)
    counter += 1

    if counter == 4:
        poly.append(verts)
        verts = []
        counter = 0

ax.add_collection3d(Poly3DCollection(poly, linewidths=1, alpha=0, edgecolors="black"))
plt.show()

# %%
scale_x, scale_y = (500, 500)
scale = (scale_x, scale_y)

edges = wireframe.sphere(.5)

polygon = raster.draw_edge_list(edges.raw(), scale)

mx = [[0 for _ in range(scale_x)] for _ in range(scale_y)]
raster.insert_points(mx, polygon)

plt.imshow(raster.convert_img(mx))
plt.show()

# %%
plt.show()
fig = plt.figure()
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

edges = wireframe.sphere(.5, circle_res=.5, res=.5)

poly = []
verts = []
counter = 0
for vec3d in edges:
    p1 = vec3d[0]
    verts.append(p1)

    if counter >= edges.sep():
        poly.append(verts)
        counter = 0
    else:
        counter += 1

ax.add_collection3d(Poly3DCollection(poly, linewidths=1, alpha=0, edgecolors="black"))
plt.show()
